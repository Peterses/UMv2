# %%
# coding=utf-8
# This is a sample Python script.

# Press ⌃R to execute it or replace it with your code.
# Press Double ⇧ to search everywhere for classes, files, tool windows, actions, and settings.

import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.base import clone
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold

from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

clfs = {
    'GNB': GaussianNB(),
    'SVM': SVC(),
    'kNN': KNeighborsClassifier()
}

datasets = [
    'cleveland',
    'appendicitis',
    'contraceptive',
    'monk-2',
    'bupa',
    'phoneme',
    'newthyroid',
    'hayes-roth',
    'winequality-white',
    'winequality-red',
    'ring',
    'banana',
    'titanic',
    'led7digit',
    'glass',
    'wine',
    'segment',
    'twonorm',
    'texture',
    'spambase'
]

# %%
# evaluate bagging algorithm for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import BaggingClassifier

model = BaggingClassifier(KNeighborsClassifier())

ensembleMethods = {
    'Bagging': BaggingClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'RandomForest': RandomForestClassifier()
}


# evaluate the model
cv = RepeatedStratifiedKFold(
    n_splits=5, 
    n_repeats=2, 
    random_state=1234
)

for data_id, singleDatset in enumerate(datasets):
    dataset = np.genfromtxt("datasets/%s.dat" % (singleDatset), delimiter=",")
    X = dataset[:, :-1]
    y = dataset[:, -1].astype(int)

    for clsf_id, classifier_name in enumerate(clfs):

        for en_id, en_method in enumerate(ensembleMethods):
            n_scores = cross_val_score(ensembleMethods[en_method], X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
            print(f'Accuracy: %.3f (%.3f) (dataset: {singleDatset}) (classif: {classifier_name}) (method: {en_method})' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.571 (0.034) (dataset: cleveland) (classif: GNB) (method: Bagging)
# Accuracy: 0.556 (0.051) (dataset: cleveland) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.579 (0.037) (dataset: cleveland) (classif: GNB) (method: RandomForest)
# Accuracy: 0.554 (0.060) (dataset: cleveland) (classif: SVM) (method: Bagging)
# Accuracy: 0.556 (0.050) (dataset: cleveland) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.576 (0.023) (dataset: cleveland) (classif: SVM) (method: RandomForest)
# Accuracy: 0.546 (0.043) (dataset: cleveland) (classif: kNN) (method: Bagging)
# Accuracy: 0.556 (0.049) (dataset: cleveland) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.581 (0.031) (dataset: cleveland) (classif: kNN) (method: RandomForest)
# Accuracy: 0.868 (0.063) (dataset: appendicitis) (classif: GNB) (method: Bagging)
# Accuracy: 0.844 (0.060) (dataset: appendicitis) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.873 (0.059) (dataset: appendicitis) (classif: GNB) (method: RandomForest)
# Accuracy: 0.877 (0.067) (dataset: appendicitis) (classif: SVM) (method: Bagging)
# Accuracy: 0.844 (0.060) (dataset: appendicitis) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.873 (0.048) (dataset: appendicitis) (classif: SVM) (method: RandomForest)
# Accuracy: 0.859 (0.059) (dataset: appendicitis) (classif: kNN) (method: Bagging)
# Accuracy: 0.859 (0.070) (dataset: appendicitis) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.868 (0.041) (dataset: appendicitis) (classif: kNN) (method: RandomForest)
# Accuracy: 0.505 (0.020) (dataset: contraceptive) (classif: GNB) (method: Bagging)
# Accuracy: 0.567 (0.026) (dataset: contraceptive) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.523 (0.041) (dataset: contraceptive) (classif: GNB) (method: RandomForest)
# Accuracy: 0.501 (0.034) (dataset: contraceptive) (classif: SVM) (method: Bagging)
# Accuracy: 0.567 (0.026) (dataset: contraceptive) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.522 (0.031) (dataset: contraceptive) (classif: SVM) (method: RandomForest)
# Accuracy: 0.512 (0.034) (dataset: contraceptive) (classif: kNN) (method: Bagging)
# Accuracy: 0.567 (0.026) (dataset: contraceptive) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.522 (0.030) (dataset: contraceptive) (classif: kNN) (method: RandomForest)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: GNB) (method: Bagging)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.993 (0.017) (dataset: monk-2) (classif: GNB) (method: RandomForest)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: SVM) (method: Bagging)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.997 (0.007) (dataset: monk-2) (classif: SVM) (method: RandomForest)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: kNN) (method: Bagging)
# Accuracy: 1.000 (0.000) (dataset: monk-2) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.994 (0.009) (dataset: monk-2) (classif: kNN) (method: RandomForest)
# Accuracy: 0.683 (0.052) (dataset: bupa) (classif: GNB) (method: Bagging)
# Accuracy: 0.728 (0.052) (dataset: bupa) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.733 (0.064) (dataset: bupa) (classif: GNB) (method: RandomForest)
# Accuracy: 0.674 (0.047) (dataset: bupa) (classif: SVM) (method: Bagging)
# Accuracy: 0.728 (0.048) (dataset: bupa) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.746 (0.052) (dataset: bupa) (classif: SVM) (method: RandomForest)
# Accuracy: 0.667 (0.042) (dataset: bupa) (classif: kNN) (method: Bagging)
# Accuracy: 0.728 (0.048) (dataset: bupa) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.742 (0.062) (dataset: bupa) (classif: kNN) (method: RandomForest)
# Accuracy: 0.893 (0.008) (dataset: phoneme) (classif: GNB) (method: Bagging)
# Accuracy: 0.856 (0.011) (dataset: phoneme) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.907 (0.008) (dataset: phoneme) (classif: GNB) (method: RandomForest)
# Accuracy: 0.891 (0.007) (dataset: phoneme) (classif: SVM) (method: Bagging)
# Accuracy: 0.856 (0.011) (dataset: phoneme) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.907 (0.008) (dataset: phoneme) (classif: SVM) (method: RandomForest)
# Accuracy: 0.894 (0.008) (dataset: phoneme) (classif: kNN) (method: Bagging)
# Accuracy: 0.856 (0.011) (dataset: phoneme) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.909 (0.006) (dataset: phoneme) (classif: kNN) (method: RandomForest)
# Accuracy: 0.947 (0.033) (dataset: newthyroid) (classif: GNB) (method: Bagging)
# Accuracy: 0.956 (0.030) (dataset: newthyroid) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.965 (0.026) (dataset: newthyroid) (classif: GNB) (method: RandomForest)
# Accuracy: 0.956 (0.030) (dataset: newthyroid) (classif: SVM) (method: Bagging)
# Accuracy: 0.956 (0.030) (dataset: newthyroid) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.963 (0.030) (dataset: newthyroid) (classif: SVM) (method: RandomForest)
# Accuracy: 0.951 (0.040) (dataset: newthyroid) (classif: kNN) (method: Bagging)
# Accuracy: 0.956 (0.030) (dataset: newthyroid) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.963 (0.035) (dataset: newthyroid) (classif: kNN) (method: RandomForest)
# Accuracy: 0.825 (0.058) (dataset: hayes-roth) (classif: GNB) (method: Bagging)
# Accuracy: 0.831 (0.049) (dataset: hayes-roth) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.812 (0.050) (dataset: hayes-roth) (classif: GNB) (method: RandomForest)
# Accuracy: 0.825 (0.037) (dataset: hayes-roth) (classif: SVM) (method: Bagging)
# Accuracy: 0.825 (0.051) (dataset: hayes-roth) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.819 (0.046) (dataset: hayes-roth) (classif: SVM) (method: RandomForest)
# Accuracy: 0.847 (0.051) (dataset: hayes-roth) (classif: kNN) (method: Bagging)
# Accuracy: 0.825 (0.051) (dataset: hayes-roth) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.834 (0.042) (dataset: hayes-roth) (classif: kNN) (method: RandomForest)
# Accuracy: 0.648 (0.016) (dataset: winequality-white) (classif: GNB) (method: Bagging)
# Accuracy: 0.593 (0.014) (dataset: winequality-white) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.685 (0.017) (dataset: winequality-white) (classif: GNB) (method: RandomForest)
# Accuracy: 0.653 (0.016) (dataset: winequality-white) (classif: SVM) (method: Bagging)
# Accuracy: 0.593 (0.013) (dataset: winequality-white) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.685 (0.020) (dataset: winequality-white) (classif: SVM) (method: RandomForest)
# Accuracy: 0.648 (0.018) (dataset: winequality-white) (classif: kNN) (method: Bagging)
# Accuracy: 0.593 (0.014) (dataset: winequality-white) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.684 (0.015) (dataset: winequality-white) (classif: kNN) (method: RandomForest)
# Accuracy: 0.668 (0.020) (dataset: winequality-red) (classif: GNB) (method: Bagging)
# Accuracy: 0.662 (0.018) (dataset: winequality-red) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.694 (0.021) (dataset: winequality-red) (classif: GNB) (method: RandomForest)
# Accuracy: 0.667 (0.026) (dataset: winequality-red) (classif: SVM) (method: Bagging)
# Accuracy: 0.660 (0.020) (dataset: winequality-red) (classif: SVM) (method: GradientBoosting)
# Accuracy: 0.692 (0.018) (dataset: winequality-red) (classif: SVM) (method: RandomForest)
# Accuracy: 0.668 (0.028) (dataset: winequality-red) (classif: kNN) (method: Bagging)
# Accuracy: 0.663 (0.019) (dataset: winequality-red) (classif: kNN) (method: GradientBoosting)
# Accuracy: 0.692 (0.022) (dataset: winequality-red) (classif: kNN) (method: RandomForest)
# Accuracy: 0.930 (0.006) (dataset: ring) (classif: GNB) (method: Bagging)
# Accuracy: 0.961 (0.004) (dataset: ring) (classif: GNB) (method: GradientBoosting)
# Accuracy: 0.949 (0.006) (dataset: ring) (classif: GNB) (method: RandomForest)
# Accuracy: 0.927 (0.010) (dataset: ring) (classif: SVM) (method: Bagging)
# Accuracy: 0.961 (0.004) (dataset: ring) (classif: SVM) (method: GradientBoosting)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6v/97h2jy0x08b9bzkr46zzl3lw0000gn/T/ipykernel_53102/3447821814.py in <module>
#      33
#      34         for en_id, en_method in enumerate(ensembleMethods):
# ---> 35             n_scores = cross_val_score(ensembleMethods[en_method], X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
#      36             print(f'Accuracy: %.3f (%.3f) (dataset: {singleDatset}) (classif: {classifier_name}) (method: {en_method})' % (mean(n_scores), std(n_scores)))
#      37
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# /usr/local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# /usr/local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /usr/local/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/local/Cellar/python@3.9/3.9.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
# model = BaggingClassifier()
# # evaluate the model
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# ensemble_Bagging_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# # report performance
# print('Accuracy: %.3f (%.3f)' % (mean(ensemble_Bagging_scores), std(ensemble_Bagging_scores)))

# %%
# np.save('results', scores)

# %%
# scores = np.load('results.npy')
# print("\nScores:\n", scores.shape)
